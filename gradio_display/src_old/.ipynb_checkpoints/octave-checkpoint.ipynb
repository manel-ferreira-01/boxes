% %%
load /tmp/out.mat

% %%
load("/tmp/out.mat")
imagesc(img)

% %%
label
% Out:
% label = [[{"bbox": [60.13970184326172, 650.3401489257812, 1494.04052734375, 2087.465576171875], "confidence": 0.8527048230171204, "class_id": 0}, {"bbox": [582.9075317382812, 49.63953399658203, 1498.80615234375, 1610.7574462890625], "confidence": 0.7395336627960205, "class_id": 0}, {"bbox": [0.3871501684188843, 882.85888671875, 301.6390686035156, 1774.0299072265625], "confidence": 0.5283493995666504, "class_id": 58}], {"aispgradio": {"user": "['a']", "input_count": 2, "timestamp": "2025-08-17T12:41:18.068862"}}]

% %%
load("/tmp/in.mat")
imagesc(img)
label
% Out:
% error: load: unable to find file /tmp/in.mat
% label =
